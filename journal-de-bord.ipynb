# %% [markdown]
# # Journal de bord

# %% [markdown]
# ## 📅 Journal de bord – Jour 1 (01/09/2026)

# %% [markdown]
# ### 🔧 Étapes / Actions réalisées
# - Tirage du binôme et appropriation de la reprise M1 (modèle + API `model` fournis)
# - Conception de l'architecture 3 services (`model` / `backend` / `frontend`) dans `docker-compose.yml`
# - `docker compose up --build` démarre les 3 services de façon reproductible, healthchecks verts
# - Pipeline CI/CD GitHub Actions + quality gate

# %% [markdown]
# ### 📝 Observations / Difficultés
# - Problèmes avec le Git
# - Joelle sur le backend / Romain sur le frontend
# - Problème de compréhension sur GitHub actions qu'on ne connaissait pas => accès manuel via l'interface Web GitHub
# - Romain : pas sûr d'avoir compris le quality gate & GHCR

# %% [markdown]
# ### ✅ Prochaines étapes
# - La suite des étapes synchrones.

# %% [markdown]
# ---

# %% [markdown]
# ## 📅 Journal de bord – Jour 2 (02/09/2026)

# %% [markdown]
# ### 🔧 Étapes / Actions réalisées
# - Endpoint `/metrics` exposé côté `model` **et** `backend`, avec métriques métier custom (erreurs upstream, latence appel interne, distribution des classes/probabilités)
# - Prometheus + Grafana câblés dans le `docker-compose.yml`
# - Dashboard Grafana provisionné automatiquement, réorganisé par priorité : service KO, latence p95 dégradée, dérive de la distribution des prédictions
# - `runbook.md` rédigé — 4 procédures (Service KO / Latence / Métrique modèle / Rollback)
# - README de démarrage

# %% [markdown]
# ### 📝 Observations / Difficultés
# - Mise en place du Grafana à intuiter.
# - Dashboard Grafana peut être à revoir car fait un peu à la va-vite par manque de temps.
# - Romain : voir le runbook plus en détail car je ne me suis pas trop penché dessus.

# %% [markdown]
# ### ✅ Prochaines étapes
# - La partie Asynchrone.

# %% [markdown]
# ## 📅 Journal de bord – Jour 3 (03/09/2026)
#
# ### 🔧 Étapes / Actions réalisées
# - M5-B2 partie synchrone
#
# ### 📝 Observations / Difficultés
# - Difficultés à comprendre ce qu'il faut vraiment faire quand c'est moi détaillé
#
# ### ✅ Prochaines étapes
# - La certification...
# - Peut être "alerte Discord webhook" sur M5-B2.
#
# ---
